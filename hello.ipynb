# %% [markdown]
# # First Assignment

# %% [markdown]
# ## First Assignment

# %% [markdown]
# ### This weeks assignment is all about getting ourselves familiar with the jupyter notebook interface

# %% [raw]
# # This weeks assignment is all about getting ourselves familiar with the jupyter notebook interface

# %% [raw]
# ## Learning is fun, but what's more fun is understanding what you are learning

# %%
import numpy as np

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
A=np.array([2,3,4,5])

# %%
B=np.array([[4,6,8,9],[6,8,8,9]])

# %%
B
# Out:
# array([[4, 6, 8, 9],
#        [6, 8, 8, 9]])

# %%
# This will show the array and the index it is located.
b=np.where(B==6)
b
# Out:
# (array([0, 1], dtype=int64), array([1, 0], dtype=int64))

# %% [markdown]
# # DATA TYPES

# %% [markdown]
# ## List (mutable)

# %%
# Lists allow duplicates, as seen below
fruits = ["apple", "banana", "orange", "apple"]
digits = [1,2,3,4,5]

# %%
print(fruits)
print(digits)
# Out:
# ['apple', 'banana', 'orange', 'apple']
# [1, 2, 3, 4, 5]

# %%
print(fruits[0])
print(digits[3])
# Out:
# apple
# 4

# %%
print(len(fruits))
print(len(digits))
# Out:
# 4
# 5

# %%
# List allows assignment.
fruits[0] = "grape"
fruits.append("mango") 
fruits
# Out:
# ['grape', 'banana', 'orange', 'apple', 'mango']

# %%
fruits.remove("mango")
fruits
# Out:
# ['apple', 'banana', 'orange', 'apple']

# %% [markdown]
# ## Dictionary (mutable)

# %%
# Dict is used to store information in Key and value as seen in the example below.
student = {
    "name": "Aliu Qudus",
    "age": 20,
    "course": "Machine Learning"
}

print(student["name"])
# Out:
# Aliu Qudus

# %%
# Dictionary allows assignment and updates
student["course"] = "Machine Learning & AI"
student["age"] = 24
student["school"] = "M4ace"

# %%
student
# Out:
# {'name': 'Aliu Qudus',
#  'age': 24,
#  'course': 'Machine Learning & AI',
#  'school': 'M4ace'}

# %%
student["school"]
# Out:
# 'M4ace'

# %% [markdown]
# ## Set (mutable)

# %%
# Sets don't allow duplicates, as seen in the output.
numbers = {1, 2, 3, 3, 4}

print(numbers)
# Out:
# {1, 2, 3, 4}

# %%
numbers.add(5)

# %%
numbers
# Out:
# {1, 2, 3, 4, 5}

# %%
# although sets might be mutable, they don't allow assignments
numbers[0] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 numbers[0] = 6
#
# TypeError: 'set' object does not support item assignment

# %%
numbers.remove(2)

# %%
numbers
# Out:
# {1, 3, 4, 5}

# %% [markdown]
# ## Tuple (not mutable)

# %%
# Tuple cannot be changed
scores = (90, 85, 90, 70)

print(scores)
# Out:
# (90, 85, 90, 70)

# %%
scores[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 scores[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
scores.append(98)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 scores.append(98)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
scores.add(98)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 scores.add(98)
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
scores
# Out:
# (90, 85, 90, 70)

# %% [markdown]
# # Simple calculator

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

operation = input("Choose operation (+, -, *, /): ")

if operation == "+":
    result = num1 + num2
elif operation == "-":
    result = num1 - num2
elif operation == "*":
    result = num1 * num2
elif operation == "/":
    if num2 != 0:
        result = num1 / num2
    else:
        result = "undefined"
else:
    result = "Invalid operation"

# Display result
print("Result:", result)
# Out:
# Enter first number:  25
# Enter second number:  0
# Choose operation (+, -, *, /):  /
# Result: undefined

# %% [markdown]
# # Login System

# %%
users = {
    "Aliu": "Learning",
    "student": "learner",
    "Chi": "drinks"
}


while True:
    username = input("Enter your username: ")
    password = input("Enter your password: ")

    if username not in users:
        print("Username not found. Please try again.\n")
    elif users[username] != password:
        print("Password is incorrect. Please try again.\n")
    else:
        print("Login successful! Welcome,", username)
        break
# Out:
# Enter your username:  Aliu
# Enter your password:  Welcome
# Password is incorrect. Please try again.
# Enter your username:  Qudus
# Enter your password:  Learning
# Username not found. Please try again.
# Enter your username:  Qud
# Enter your password:  Wel
# Username not found. Please try again.
# Enter your username:  Aliu
# Enter your password:  Learning
# Login successful! Welcome, Aliu

# %% [markdown]
# # Declare all the data structure with varying samples

# %% [markdown]
# # List

# %%
# Lists allow duplicates, as seen below
fruits = ["apple", "banana", "orange", "apple"]
digits = [1,2,3,4,5]

# %%
digits.sort()
fruits.sort()

# %%
fruits
# Out:
# ['apple', 'apple', 'banana', 'orange']

# %%
digits
# Out:
# [1, 2, 3, 4, 5]

# %%
print(fruits)
print(digits)
# Out:
# ['apple', 'apple', 'banana', 'orange']
# [1, 2, 3, 4, 5]

# %%
print(fruits[0])
print(digits[3])
# Out:
# apple
# 4

# %%
print(len(fruits))
print(len(digits))
# Out:
# 4
# 5

# %%
# List allows assignment.
fruits[0] = "grape"
fruits.append("mango") 
fruits
# Out:
# ['grape', 'apple', 'banana', 'orange', 'mango']

# %%
fruits.remove("mango")
fruits
# Out:
# ['grape', 'apple', 'banana', 'orange']

# %% [markdown]
# # Dictionary

# %%
# Dict is used to store information in Key and value as seen in the example below.
student = {
    "name": "Aliu Qudus",
    "age": 20,
    "course": "Machine Learning"
}

print(student["name"])
# Out:
# Aliu Qudus

# %%
# Dictionary allows assignment and updates
student["course"] = "Machine Learning & AI"
student["age"] = 24
student["school"] = "M4ace"

# %%
student
# Out:
# {'name': 'Aliu Qudus',
#  'age': 24,
#  'course': 'Machine Learning & AI',
#  'school': 'M4ace'}

# %%
student["school"]
# Out:
# 'M4ace'

# %% [markdown]
# # Set

# %%
# Sets don't allow duplicates, as seen in the output.
numbers = {1, 2, 3, 3, 4,10}
digits = {4,5,6,5,2,2,7}

print(numbers)
print(digits)
# Out:
# {1, 2, 3, 4, 10}
# {2, 4, 5, 6, 7}

# %%
numbers.add(5)
digits.add(3)
digits.pop()
# Out:
# 2

# %%
digits
# Out:
# {3, 4, 5, 6, 7}

# %%
numbers
# Out:
# {1, 2, 3, 4, 5}

# %%
# although sets might be mutable, they don't allow assignments
numbers[0] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 2
#       1 # although sets might be mutable, they don't allow assignments
# ----> 2 numbers[0] = 6
#
# TypeError: 'set' object does not support item assignment

# %%
numbers.remove(10)

# %%
numbers
# Out:
# {1, 2, 3, 4}

# %%
union = numbers.union(digits)
union
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
diff = numbers.difference(digits)
diff
# Out:
# {1, 3}

# %%
intersect = numbers.intersection(digits)
intersect
# Out:
# {2, 4}

# %% [markdown]
# # Tuple

# %%
# Tuple cannot be changed
scores = (90, 85, 90, 70)

print(scores)
# Out:
# (90, 85, 90, 70)

# %%
scores[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 scores[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
scores.append(98)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 scores.append(98)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
scores.add(98)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 scores.add(98)
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
scores
# Out:
# (90, 85, 90, 70)
